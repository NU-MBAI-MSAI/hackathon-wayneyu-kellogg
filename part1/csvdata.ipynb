# %%
import csv
import numpy as np
import matplotlib.pyplot as plt

# %%
infile = open("data.csv")
data = csv.reader(infile)
names = next(data) # column names
for row in data:
    print(row[1]) # 2nd column
# Out:
# Salt Lake City, UT
# Allentown, PA
# Orono, ME
# Harrisonburg, VA
# East Lansing, MI

# %%
infile = open("cohort.csv")
data = csv.reader(infile)
names = next(data)
values = []
for row in data:
    values.append(row[names.index('UGDS')])

# %%
plt.hist(values)
plt.show()
